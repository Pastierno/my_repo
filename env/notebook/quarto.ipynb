# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
# Creaiamo dataset di esempio
np.random.seed(42)
X = np.random.rand(200, 5)

# %%
# Visualizziamo i dati originali
plt.scatter(X[:, 0], X[:, 1], alpha=0.5)
plt.title("Dati Originali")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()

# %%
# Normalizziamo le feature
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Applichiamo PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
print("Varianza spiegata da ciascun componente principale:")
print(pca.explained_variance_ratio_)
# Out:
# Varianza spiegata da ciascun componente principale:
# [0.26542666 0.20580487]

# %%
plt.scatter(X_pca[:, 0], X_pca[:, 1], c="blue", edgecolor="k", alpha=0.7)
plt.title("Dati dopo PCA")
plt.xlabel("Componente Principale 1")
plt.ylabel("Componente Principale 2")
plt.show()
